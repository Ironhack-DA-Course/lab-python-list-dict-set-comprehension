# %% [markdown]
# # Lab | List, Dict and Set Comprehension

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized with Comprehension

# %% [markdown]
# In the previous exercise, you developed a program to manage customer orders and inventory. Now, let's take it a step further and incorporate comprehension into your code.
#
# Follow the steps below to complete the exercise:
#
# 1. Review your code from the previous exercise and identify areas where you can apply comprehension to simplify and streamline your code.
#
#     - *Hint: Apply it to initialize inventory, updating the inventory and printing the updated inventory.*
#
#     - For example, in initializing the inventory, we could have:
#
#         ```python
#         def initialize_inventory(products):
#             inventory = {product: int(input(f"Enter the quantity of {product}s available: ")) for product in products}
#             return inventory
#
#         ```
# <br>
#
#
# 2. Modify the function get_customer_orders so it prompts the user to enter the number of customer orders and gathers the product names using a loop and user input. Use comprehension.
#
# 3. Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.
#
# 4. Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.
#
# 5. Print the total price of the customer order.
#
# Your code should produce output similar to the following:
#
# ```python
# Enter the quantity of t-shirts available:  5
# Enter the quantity of mugs available:  4
# Enter the quantity of hats available:  3
# Enter the quantity of books available:  2
# Enter the quantity of keychains available:  1
# Enter the number of customer orders:  2
# Enter the name of a product that a customer wants to order:  hat
# Enter the name of a product that a customer wants to order:  keychain
#
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Unique Products Ordered: 40.0
#
# Updated Inventory:
# t-shirt: 5
# mug: 4
# hat: 2
# book: 2
# Enter the price of keychain:  5
# Enter the price of hat:  10
# Total Price: 15.0
#
# ```

# %%
from pydantic_core import ErrorTypeInfo

products_input = input("Enter list of products separated by space")
try:
    products = products_input.split()
except:
    raise ErrorTypeInfo("Invalid Input")

# %%
def initialize_inventory(products: list):
    try:
        inventory = {product: int(input(f"Enter the quantity of {product}s available: ")) for product in products}
    except:
        print("Quantity is not a number")
    return inventory

# %%
begin_inventory = initialize_inventory(products)

# %%
def get_customer_orders():
    '''Enter Product Name'''
    try:
        cust_orders_num = int(input(f"Enter the number of customer orders: "))
    except:
        raise ErrorTypeInfo("Total customer orders must be int")
    
    customer_orders_input = [input(f"Enter the name of a product that a customer wants to order:") for i in range(0,cust_orders_num)]
    customer_orders = [order for order in customer_orders_input if order in products]
    return set(customer_orders)

# %%
orders = get_customer_orders()

# %%
def calculate_order_statistics(customer_orders: set, products: list):
    '''calculate  order statistics (total products ordered and percentage of unique products ordered'''
    total_prod_ordered = len(customer_orders)
    total_prods = len(set(products))
    percent_unique = (total_prod_ordered / total_prods) * 100
    return  {
              "Total Products Ordered" : total_prod_ordered,
              "Percentage of Unique Products Ordered": percent_unique
            }

# %%
statistics = calculate_order_statistics(customer_orders=orders, products=products )

# %%
def print_order_statistics(order_statistics):
#     print(f"Total prod ordered: {order_statistics[0]}")
#     print(f"Percentage of unique products ordered {order_statistics[1]}")
    print("Order Statistics:")
    print_statistic = {print(f"{key}: {val}") for key,val in order_statistics.items()}
    return print_statistic

# %%
print_order_statistics(statistics)

# %%
def update_inventory(customer_orders: set, inventory: list):
    '''Update inventory dict based on customer orders'''
    new_inventory = {elem[0]: elem[1]-1 if elem[0] in customer_orders and elem[1] > 0 else elem[1] for elem in inventory.items()}
    # new_inventory = {new_inventory.__delitem__(elem[0]) for elem in new_inventory.items() if elem[1] == 0 }    
    new_inventory = {key: val for key, val in new_inventory.items() if val > 0}        
    return new_inventory

# %%
new_inventory = update_inventory(customer_orders = orders,inventory=begin_inventory )

# %%
def print_updated_inventory(inventory: dict):
    print("Updated Inventory:")
    print_update_inventory = {print(f"Product {key}: {val}") for key,val in inventory.items()}
    return print_update_inventory

# %%
print_updated_inventory(new_inventory)

# %%
def calculate_total_unitprice(customer_orders: set):
    unit_prices = [input(f"Enter the price of {order}:") for order in customer_orders]
    unit_prices = [int(price) for price in unit_prices]
    return sum(unit_prices)

# %%
total_unit_price = calculate_total_unitprice(orders)
print (f"Total Price: {total_unit_price}")
